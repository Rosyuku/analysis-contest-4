# %%
from glob import glob
import pandas as pd
from IPython.core.display import display
# %matplotlib inline

# %%
dataList = glob("Data/*.csv")

# %%
dataList
# Out:
# ['Data\\equipment_A.csv',
#  'Data\\equipment_B.csv',
#  'Data\\equipment_C.csv',
#  'Data\\equipment_D.csv',
#  'Data\\index_master.csv',
#  'Data\\sample_submit.csv',
#  'Data\\track_A.csv',
#  'Data\\track_B.csv',
#  'Data\\track_C.csv',
#  'Data\\track_D.csv']

# %%
fileName = dataList[0]

# %%
df = pd.read_csv(fileName)
display(df.head())
display(df.describe())
df.plot(subplots=True, figsize=(20, 20), title=fileName)
# Out:
#      キロ程  バラスト  ロングレール  マクラギ種別  橋りょう  踏切     通トン  曲線半径  フラグ
# 0  10000     1       1       3     0   0  13.607     0    1
# 1  10001     1       1       3     0   0  13.607     0    1
# 2  10002     1       1       3     0   0  13.607     0    1
# 3  10003     1       1       3     0   0  13.607     0    1
# 4  10004     1       1       1     0   0  13.607     0    1
#                 キロ程          バラスト        ロングレール        マクラギ種別          橋りょう  \
# count  27906.000000  27906.000000  27906.000000  27906.000000  27906.000000
# mean   23952.500000      0.597076      0.882857      1.232925      0.023830
# std     8055.912642      0.490495      0.321597      0.953346      0.152522
# min    10000.000000      0.000000      0.000000      1.000000      0.000000
# 25%    16976.250000      0.000000      1.000000      1.000000      0.000000
# 50%    23952.500000      1.000000      1.000000      1.000000      0.000000
# 75%    30928.750000      1.000000      1.000000      1.000000      0.000000
# ...

# %%
fileName = dataList[4]

# %%
df = pd.read_csv(fileName)
display(df.head())
display(df.describe())
# Out:
#    id 路線        date    キロ程
# 0   0  A  2018-04-01  10000
# 1   1  A  2018-04-01  10001
# 2   2  A  2018-04-01  10002
# 3   3  A  2018-04-01  10003
# 4   4  A  2018-04-01  10004
#                  id           キロ程
# count  1.099389e+07  1.099389e+07
# mean   5.496946e+06  2.899283e+04
# std    3.173663e+06  1.462188e+04
# min    0.000000e+00  1.000000e+04
# 25%    2.748473e+06  1.755000e+04
# 50%    5.496946e+06  2.510100e+04
# 75%    8.245418e+06  3.669300e+04
# max    1.099389e+07  6.568300e+04

# %%
#df.plot.hist(subplots=True)

# %%
fileName = dataList[6]

# %%
df = pd.read_csv(fileName, index_col=[0, 1])
display(df.head())
display(df.describe())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:463: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                    高低左   高低右   通り左   通り右    水準    軌間    速度
# date       キロ程
# 2017-04-01 10000 -1.16 -0.23  1.20  1.20  0.83  3.89  84.0
#            10001 -1.17 -0.30  1.88  1.88  0.67  4.63  84.0
#            10002 -1.09 -0.19  2.30  2.30  0.50  5.33  84.0
#            10003 -0.64  0.20  2.28  2.28  0.46  5.90  84.0
#            10004  0.47  0.89  1.74  1.74  0.62  6.38  84.5
#                 高低左           高低右           通り左           通り右            水準  \
# count  7.470943e+06  7.471012e+06  7.446377e+06  7.446377e+06  7.446377e+06
# mean   1.567537e-03  2.756957e-03  5.495526e-03 -2.827986e-03 -4.965998e-03
# std    1.773254e+00  1.825382e+00  1.239223e+00  1.270356e+00  1.251522e+00
# min   -2.607000e+01 -2.559000e+01 -8.474000e+01 -8.644000e+01 -1.815000e+01
# ...

# %%
df.loc[pd.IndexSlice[:, 10000], :].plot(subplots=True, figsize=(20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000170F4F7CA58>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017080082908>], dtype=object)

# %%
df.loc[pd.IndexSlice['2017-04-01', :], :].plot(subplots=True, figsize=(20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000170F4F7CE80>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001708074DDD8>], dtype=object)
